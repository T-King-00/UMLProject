# %%
import plantUML, helperFunctions, extractSVO
import spacy
import requests

response = requests.get ( 'https://raw.githubusercontent.com/T-King-00/Gp-AutomationOfBaTasks/tony/university.txt' )
file = response.text
sentences = helperFunctions.getSentencesFromFile ( file )
from spacy import displacy

#for i, sent in enumerate(sentences):
x = 10
v = sentences [ x ].find ( "so that" )
sentVar = sentences [ x ] [ 0:v ]
sentVar = helperFunctions.reduceSentence ( sentVar )
extractSVO.svoExtraction ( sentVar )
displacy.render ( helperFunctions.nlp ( sentences [ x ] ), style='dep', jupyter=True )
extractSVO.extract_object_phrase ( sentVar )
# Out:
# After reducing sentence ::  As participant , I want to receive feedback after quiz question
# Root is : want
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="882d4ab73684409bacc80acf49b08a86-0" class="displacy" width="4600" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# ...
